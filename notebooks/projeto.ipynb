# %% [markdown]
# # Analise exploratoria

# %%
import pandas as pd

# %%
import pathlib

datafile = pathlib.Path.cwd().parent / 'data' / 'auto-mpg.data'

# %%
columns = [
    'mpg',
    'cylinders',
    'displacement',
    'horsepower',
    'weight',
    'acceleration',
    'model year',
    'origin',
    'car',
]

data = pd.read_csv(datafile, names=columns, delim_whitespace=True)

# %%
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 1    15.0          8         350.0      165.0  3693.0          11.5
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      model year  origin                        car
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car           398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %% [markdown]
# - Não tem valor faltante
# - mpg é o target
# - car é o nome do modelo - descartar
# - ver o que aconteceu com horsepower

# %% [markdown]
# # mpg

# %%
data['mpg'].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # cylinders

# %%
data['cylinders'].value_counts().sort_index()
# Out:
# 3      4
# 4    204
# 5      3
# 6     84
# 8    103
# Name: cylinders, dtype: int64

# %% [markdown]
# # displacement

# %%
data['displacement'].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Relação entre o target e o displacement

# %%
data.plot.scatter(x='displacement', y='mpg')
# Out:
# <Axes: xlabel='displacement', ylabel='mpg'>

# %% [markdown]
# # horsepower

# %%
def limpa_horsepower(texto):
    if texto == '?':
        return None
    return float(texto)

data['horsepower'] = data['horsepower'].apply(limpa_horsepower).astype(float)

# %%
data['horsepower'].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.plot.scatter(x='horsepower', y='mpg')
# Out:
# <Axes: xlabel='horsepower', ylabel='mpg'>

# %% [markdown]
# # weight

# %%
data['weight'].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.plot.scatter(x='weight', y='mpg')
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %% [markdown]
# # acceleration

# %%
data['acceleration'].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.plot.scatter(x='acceleration', y='mpg')
# Out:
# <Axes: xlabel='acceleration', ylabel='mpg'>

# %% [markdown]
# # model year

# %%
data['model year'].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.plot.scatter(x='model year', y='mpg')
# Out:
# <Axes: xlabel='model year', ylabel='mpg'>

# %% [markdown]
# # origin

# %%
data['origin'].value_counts()
# Out:
# 1    249
# 3     79
# 2     70
# Name: origin, dtype: int64

# %%
data[['mpg', 'origin']].plot.box(by='origin')
# Out:
# mpg    Axes(0.125,0.11;0.775x0.77)
# dtype: object
